# %%
# Removing NA values
import pandas as pd
import numpy as np

d1 = {'Name': ['Pankaj', 'Meghna', 'David', 'Lisa'], 
      'ID': [1, 2, 3, 4], 
      'Salary': [100, 200, np.nan, pd.NaT],
      'Role': ['CEO', None, pd.NaT, pd.NaT]}

df = pd.DataFrame(d1)
print(df)

# drop all rows with any NaN and NaT values
df1 = df.dropna()
print(df1)
# Out:
#      Name  ID Salary  Role
# 0  Pankaj   1    100   CEO
# 1  Meghna   2    200  None
# 2   David   3    NaN   NaT
# 3    Lisa   4    NaT   NaT
#      Name  ID Salary Role
# 0  Pankaj   1    100  CEO

# %%
# Dropping rows with NA values
import pandas as pd

d1 = {'Name': ['Pankaj', 'Meghna'], 'ID': [1, 2], 'Salary': [pd.NaT, 100]}
df = pd.DataFrame(d1)

print(df)

df.dropna(inplace=True)
print(df)
# Out:
#      Name  ID Salary
# 0  Pankaj   1    NaT
# 1  Meghna   2    100
#      Name  ID Salary
# 1  Meghna   2    100

# %%
# Drop Row/Column Only if All the Values are Null
import pandas as pd
import numpy as np

d1 = {'Name': ['Pankaj', 'Meghna', 'David', pd.NaT], 
      'ID': [1, 2, 3, pd.NaT], 
      'Salary': [100, 200, np.nan, pd.NaT],
      'Role': [np.nan, np.nan, pd.NaT, pd.NaT]}

df = pd.DataFrame(d1)
print(df)

df1 = df.dropna(how='all')
print(df1)

df1 = df.dropna(how='all', axis=1)
print(df1)
# Out:
#      Name   ID Salary Role
# 0  Pankaj    1    100  NaT
# 1  Meghna    2    200  NaT
# 2   David    3    NaN  NaT
# 3     NaT  NaT    NaT  NaT
#      Name ID Salary Role
# 0  Pankaj  1    100  NaT
# 1  Meghna  2    200  NaT
# 2   David  3    NaN  NaT
#      Name   ID Salary
# 0  Pankaj    1    100
# 1  Meghna    2    200
# 2   David    3    NaN
# 3     NaT  NaT    NaT

# %%
# Imputing example
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston
 
boston_bunch = load_boston()
dfx = pd.DataFrame(boston_bunch.data, columns = boston_bunch.feature_names) #independent variables
dfy = pd.DataFrame(boston_bunch.target, columns = ['target']) #dependent variables
boston = dfx.join(dfy)
boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
# Finding the sum of null values
boston.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
# Changing 20% values to NaN
import collections
import random
df = boston
replaced = collections.defaultdict(set)
ix = [(row, col) for row in range(df.shape[0]) for col in range(df.shape[1])]
random.shuffle(ix)
to_replace = int(round(.2*len(ix)))
for row, col in ix:
    if len(replaced[row]) < df.shape[1] - 1:
        df.iloc[row, col] = np.nan
        to_replace -= 1
        replaced[row].add(col)
        if to_replace == 0:
            break

# %%
# Finding the sum of null values
boston.isnull().sum()
# Out:
# CRIM       117
# ZN         104
# INDUS       95
# CHAS       105
# NOX        111
# RM         109
# AGE         85
# DIS         86
# RAD         95
# TAX        101
# PTRATIO    107
# B           95
# LSTAT      110
# target      97
# dtype: int64

# %%
# Fill NA with mean() of each column in boston dataset
df = df.apply(lambda x: x.fillna(x.mean()),axis=0)
df.head()
# Out:
#        CRIM         ZN      INDUS      CHAS    NOX      RM        AGE  \
# 0  0.006320  18.000000   2.310000  0.067332  0.538  6.2897  65.200000
# 1  0.027310   0.000000   7.070000  0.067332  0.469  6.4210  68.339192
# 2  0.027290   0.000000  11.328856  0.000000  0.469  7.1850  61.100000
# 3  3.766377  11.345771   2.180000  0.067332  0.458  6.9980  45.800000
# 4  3.766377   0.000000   2.180000  0.067332  0.458  7.1470  68.339192
#
#         DIS       RAD         TAX  PTRATIO           B      LSTAT     target
# 0  3.684959  9.559611  296.000000     15.3  396.900000   4.980000  22.707579
# 1  4.967100  2.000000  242.000000     17.8  352.523917   9.140000  21.600000
# 2  4.967100  2.000000  242.000000     17.8  392.830000   4.030000  34.700000
# 3  6.062200  3.000000  410.945679     18.7  394.630000  12.567197  33.400000
# 4  6.062200  3.000000  222.000000     18.7  352.523917   5.330000  36.200000

# %%
# Finding the sum of null values
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# target     0
# dtype: int64

# %%
# Z-Score
import numpy as np
from scipy import stats
    
arr1 = [[20, 2, 7, 1, 34],
        [50, 12, 12, 34, 4]]
  
arr2 = [[50, 12, 12, 34, 4], 
        [12, 11, 10, 34, 21]]
  
print ("\narr1 : ", arr1)
print ("\narr2 : ", arr2)

print ("\nZ-score for arr1 : \n", stats.zscore(arr1, axis = 1))
# Out:
# arr1 :  [[20, 2, 7, 1, 34], [50, 12, 12, 34, 4]]
#
# arr2 :  [[50, 12, 12, 34, 4], [12, 11, 10, 34, 21]]
#
# Z-score for arr1 :
#  [[ 0.57251144 -0.85876716 -0.46118977 -0.93828264  1.68572813]
#  [ 1.62005758 -0.61045648 -0.61045648  0.68089376 -1.08003838]]

# %%
# Min-Max Scalar
from numpy import asarray
from sklearn.preprocessing import MinMaxScaler
# define data
data = asarray([[100, 0.001],
                [8, 0.05],
                [50, 0.005],
                [88, 0.07],
                [4, 0.1]])
print(data)
# define min max scaler
scaler = MinMaxScaler()
# transform data
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[1.0e+02 1.0e-03]
#  [8.0e+00 5.0e-02]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]
#  [4.0e+00 1.0e-01]]
# [[1.         0.        ]
#  [0.04166667 0.49494949]
#  [0.47916667 0.04040404]
#  [0.875      0.6969697 ]
#  [0.         1.        ]]

# %%
# Standardization
from numpy import asarray
from sklearn.preprocessing import StandardScaler
# define data
data = asarray([[100, 0.001],
                [8, 0.05],
                [50, 0.005],
                [88, 0.07],
                [4, 0.1]])
print(data)
# define standard scaler
scaler = StandardScaler()
# transform data
scaled = scaler.fit_transform(data)
print(scaled)
# Out:
# [[1.0e+02 1.0e-03]
#  [8.0e+00 5.0e-02]
#  [5.0e+01 5.0e-03]
#  [8.8e+01 7.0e-02]
#  [4.0e+00 1.0e-01]]
# [[ 1.26398112 -1.16389967]
#  [-1.06174414  0.12639634]
#  [ 0.         -1.05856939]
#  [ 0.96062565  0.65304778]
#  [-1.16286263  1.44302493]]

# %%
# Label Encoding

import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
# creating initial dataframe
bridge_types = ('Arch','Beam','Truss','Cantilever','Tied Arch','Suspension','Cable')
bridge_df = pd.DataFrame(bridge_types, columns=['Bridge_Types'])
# creating instance of labelencoder
labelencoder = LabelEncoder()
# Assigning numerical values and storing in another column
bridge_df['Bridge_Types_Cat'] = labelencoder.fit_transform(bridge_df['Bridge_Types'])
bridge_df
# Out:
#   Bridge_Types  Bridge_Types_Cat
# 0         Arch                 0
# 1         Beam                 1
# 2        Truss                 6
# 3   Cantilever                 3
# 4    Tied Arch                 5
# 5   Suspension                 4
# 6        Cable                 2

# %%
# One Hot Encoding Example
one_hot_encoded = pd.get_dummies(bridge_df, columns = ['Bridge_Types'])
one_hot_encoded
